# %%
import pandas as pd 
from pathlib import Path
import sqlite3
import pandas as pd


data_folder = Path('data')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 from pathlib import Path
#       3 import sqlite3
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# /bin/bash: pip: command not found

# %%
persona_df = pd.read_csv(data_folder / Path('generated_personas.csv'))
persona_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 persona_df = pd.read_csv(data_folder / Path('generated_personas.csv'))
#       2 persona_df.head()
#
# NameError: name 'pd' is not defined

# %%
persona_df.iloc[0]['description']
# Out:
# 'The user is from Brazil, expressing strong anti-lockdown and anti-COVID-19 sentiment, often using informal language and internet slang. They frequently mention the virus in relation to travel, personal health, and political figures.'

# %%
persona_df.iloc[0]['user_char']
# Out:
# 'The user has a sarcastic and confrontational tone, showing defiance towards government measures and public health guidelines while maintaining respect for certain social causes. They engage interactively with others, often using humor and memes.'

# %%
# Connect to the .db file
conn = sqlite3.connect("database/exp_64_agents_20260630_110357.db")

# Read a table into a DataFrame
df = pd.read_sql_query("SELECT * FROM user", conn)
df.iloc[0]['bio']
# Out:
# 'A healthcare professional dealing with the aftermath of the COVID-19 pandemic, balancing personal and professional life while advocating for better health policies and patient care.'
