# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
! python3 node_prunning.py --graph large_user_similarity_graph.gexf --output large_user_similarity_graph_pruned.gexf
# Out:
# 485 485
# Loaded graph large_user_similarity_graph.gexf with 485 nodes and 6458 edges
# Computed eigenvector centrality
# [1.         0.17317455 0.17317455 0.17317455 0.17317455 0.17317455
#  0.17317455 0.17317455 0.17317455 0.17317455 0.17317455 0.17317455
#  0.17317455 0.17317455 0.17317455 0.17317455 0.17317455 0.17317455
#  0.17317455 0.17317455 0.17317455 0.17317455 0.17317455 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.17164168 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.17164168 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.17164168 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.17164168 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.17164168 0.17164168
#  0.17164168 0.17164168 0.17164168 0.17164168 0.16869962 0.16869962
#  0.16869962 0.16869962 0.16869962 0.16869962 0.16869962 0.16869962
#  0.16869962 0.16869962 0.16869962 0.16869962 0.16869962 0.16869962
# ...

# %%
G = nx.read_gexf('large_user_similarity_graph_pruned.gexf')
#plot 
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(G, seed=42)
nx.draw(G, pos, node_size=20, edge_color='gray', alpha=0.5)
plt.title("Pruned User Similarity Graph")
plt.show()
